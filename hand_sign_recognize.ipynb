# %%
from ultralytics import YOLO

pathModel = "resultTrain/handSignRecognize2/weights/best.pt"
model = YOLO(pathModel)
pathTest = "test"

# %%
from IPython.display import display
from PIL import Image as PILImage

# %%
for i, result in enumerate(model.predict(source=pathTest, save=True, project='resultPredict',name='handSignRecognize', exist_ok=True)):
    hasil_plot_array = result.plot(conf=True) # gambar hasil dideteksi sebagai array numPy
    hasil_plot_rgb = hasil_plot_array[:, :, ::-1] # konversi dari BGR ke RGB
    gambar_final = PILImage.fromarray(hasil_plot_rgb) # obj gambar dari numPy dengan PIL
    print(f"\n=>> hasil untuk gambar #{i+1} ({result.path.split('/')[-1]})")
    display(gambar_final)
# Out:
# image 1/58 d:\ASL\test\A84.jpg: 640x640 1 A, 564.8ms
# image 2/58 d:\ASL\test\A85.jpg: 640x640 1 A, 502.7ms
# image 3/58 d:\ASL\test\A86.jpg: 640x640 1 A, 410.8ms
# image 4/58 d:\ASL\test\A87.jpg: 640x640 1 A, 397.9ms
# image 5/58 d:\ASL\test\A88.jpg: 640x640 1 A, 383.5ms
# image 6/58 d:\ASL\test\A89.jpg: 640x640 1 A, 383.4ms
# image 7/58 d:\ASL\test\A90.jpg: 640x640 1 A, 406.4ms
# image 8/58 d:\ASL\test\A91.jpg: 640x640 1 A, 400.8ms
# image 9/58 d:\ASL\test\A92.jpg: 640x640 1 A, 388.4ms
# image 10/58 d:\ASL\test\A93.jpg: 640x640 1 A, 367.1ms
# image 11/58 d:\ASL\test\A94.jpg: 640x640 1 A, 350.1ms
# image 12/58 d:\ASL\test\A95.jpg: 640x640 1 A, 318.9ms
# image 13/58 d:\ASL\test\A96.jpg: 640x640 1 A, 329.6ms
# image 14/58 d:\ASL\test\B85.jpg: 640x640 1 B, 307.9ms
# image 15/58 d:\ASL\test\B86.jpg: 640x640 1 B, 321.5ms
# image 16/58 d:\ASL\test\B87.jpg: 640x640 1 B, 309.9ms
# image 17/58 d:\ASL\test\B88.jpg: 640x640 1 B, 308.6ms
# image 18/58 d:\ASL\test\B89.jpg: 640x640 1 B, 308.0ms
# ...

# %%
# Real-time test model YOLOv8 dengan webcam berdasarkan best model yang telah dilatih

import cv2

cap = cv2.VideoCapture(0)  # Gunakan webcam default

while True:
    ret, frame = cap.read()
    if not ret:
        break

    # Prediksi dengan model YOLOv8 yang sudah dilatih
    results = model.predict(frame)
    result = results[0]
    hasil_plot_array = result.plot(conf=True)

    cv2.imshow("Hand Sign Recognition - Real Time", hasil_plot_array)

    # Tekan 'q' untuk keluar
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 (no detections), 252.0ms
# Speed: 20.8ms preprocess, 252.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 276.1ms
# Speed: 6.3ms preprocess, 276.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 242.7ms
# Speed: 4.9ms preprocess, 242.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 A, 253.9ms
# Speed: 3.4ms preprocess, 253.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 249.4ms
# Speed: 3.3ms preprocess, 249.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 F, 199.0ms
# Speed: 3.2ms preprocess, 199.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 222.4ms
# Speed: 4.6ms preprocess, 222.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 204.2ms
# ...
